# %%
import sys
sys.path.append('..')
from detector.elephant_detector import ElephantDetector

# %%
PATH_TO_WEIGHTS = '../train_detector/runs/best_run/train/weights/best.pt'
detector = ElephantDetector(PATH_TO_WEIGHTS)
# Out:
# device = cuda

# %%
detector.model.val(data='config.yaml', split='test', conf=0.5)
# Out:
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /home/improcloud/nguyehu7/BP/train_detector/target/labels/test.cac
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        986       1894      0.961      0.972      0.979      0.769
# Speed: 0.3ms preprocess, 6.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7efc2c5ae9d0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...

# %%
original_detector = ElephantDetector()
original_detector.model.val(data='config2.yaml', split='test', conf = 0.5,  classes =[20])
# Out:
# device = cuda
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
# val: Scanning /home/improcloud/nguyehu7/BP/train_detector/target/labels/test2.ca
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        986       1894      0.961      0.547      0.762      0.492
#               elephant        986       1894      0.961      0.547      0.762      0.492
# Speed: 0.3ms preprocess, 6.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([20])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7efc2c650910>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...
